# %% [markdown]
# <a href="https://colab.research.google.com/github/manojec054/Assignment/blob/master/Artificial_Neural_Network_Original.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Artificial Neural Networks
#
# An ANN is based on a collection of connected units or nodes called artificial neurons, which loosely model the neurons in a biological brain. Each connection, like the synapses in a biological brain, can transmit a signal from one artificial neuron to another. An artificial neuron that receives a signal can process it and then signal additional artificial neurons connected to it.
#
#
# ![alt text](https://askabiologist.asu.edu/sites/default/files/resources/articles/neuron_anatomy.jpg)
#
# A Diagram of Neuron Cell

# %% [markdown]
# ### Perceptron
#
# In machine learning, the perceptron is an algorithm for supervised learning of binary classifiers. A binary classifier is a function which can decide whether or not an input, represented by a vector of numbers, belongs to some specific class. It is a type of linear classifier, i.e. a classification algorithm that makes its predictions based on a linear predictor function combining a set of weights with the feature vector.
#
# ![alt text](https://cdn-images-1.medium.com/max/1600/1*n6sJ4yZQzwKL9wnF5wnVNg.png)

# %% [markdown]
# Lets see a sample implementation of Neural Network.

# %%
import numpy as np
import scipy as sp
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
# input and output layer dimension
class Config:
  nn_input_dim = 2  # no. of nodes of input layer
  nn_output_dim = 2 # no. of nodes of output layer
  
	# Gradient descent parameters
  epsilon = 0.01 # same as alpha
  reg_lambda = 0.0001 # penalty term

# %%
def draw_visualization(X, Y, model):
  plot_decision_boundary(lambda x:predict(model,x), X, Y)

# %%
def plot_decision_boundary(pred_func, X, y):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    h = 0.01
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole gid
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Spectral)
    plt.show()

# %%
# Calculate loss of the neural model
def calculate_loss(model, X, Y):
  data_size = len(X)
  W1, b1, W2, b2 = model['W1'], model['b1'], model['W2'], model['b2']

    # Forward propagation to calculate our predictions	
  z1 = X.dot(W1) + b1
  a1 = np.tanh(z1) # activation function
  z2 = a1.dot(W2) + b2
  
  exp_scores = np.exp(z2)
  probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)
  
	# Calculating the loss
  corect_logprobs = -np.log(probs[range(data_size), Y])
  data_loss = np.sum(corect_logprobs)

	# Add regularization term to loss
  data_loss += Config.reg_lambda/2 * (np.sum(np.square(W1)) + np.sum(np.square(W2)))
  return 1./data_size * data_loss

# %%
# probs = np.array([0.37, 0.63])
# print(probs[range(2), 1])

# %%
def predict(model, x):
	W1, b1, W2, b2 = model['W1'], model['b1'], model['W2'], model['b2']
	# forward propagation
	z1 = x.dot(W1) + b1
	a1 = np.tanh(z1)
	z2 = a1.dot(W2) + b2
	output_scores = np.exp(z2)
	probs = output_scores / np.sum(output_scores, axis=1, keepdims=True)
	return np.argmax(probs, axis=1)

# %%
def build_training_model(X, Y, nn_hidden_dim, num_passes = 5000, print_loss = True):

	data_size = len(X)
	np.random.seed(0)
	W1 = np.random.randn(Config.nn_input_dim, nn_hidden_dim) / np.sqrt(Config.nn_input_dim) # Xavier's Intialization
	b1 = np.zeros((1, nn_hidden_dim))
	W2 = np.random.randn(nn_hidden_dim, Config.nn_output_dim) / np.sqrt(nn_hidden_dim)
	b2 = np.zeros((1, Config.nn_output_dim))
    

	model = {}

	for i in range(0, num_passes):

	    # Forward propagation
	    z1 = X.dot(W1) + b1
	    a1 = np.tanh(z1)
	    z2 = a1.dot(W2) + b2
	    exp_scores = np.exp(z2)
	    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True)

	    delta3 = probs
	    delta3[range(data_size), Y] -= 1
	    dW2 = (a1.T).dot(delta3)
	    db2 = np.sum(delta3, axis=0, keepdims=True)
	    delta2 = delta3.dot(W2.T) * (1 - np.power(a1, 2))
	    dW1 = np.dot(X.T, delta2)
	    db1 = np.sum(delta2, axis=0)

	    # Add regularization terms (b1 and b2 don't have regularization terms)
	    dW2 += Config.reg_lambda * W2
	    dW1 += Config.reg_lambda * W1

	    # Gradient descent parameter update
	    W1 += -Config.epsilon * dW1
	    b1 += -Config.epsilon * db1
	    W2 += -Config.epsilon * dW2
	    b2 += -Config.epsilon * db2

	    # Assign new parameters to the model
	    model = {'W1': W1, 'b1': b1, 'W2': W2, 'b2': b2}

	    # Optionally print the loss.
	    # This is expensive because it uses the whole dataset, so we don't want to do it too often.
	    if print_loss and i % 500 == 0:
	        print("Loss after iteration %i: %f" % (i, calculate_loss(model, X, Y)))

	return model

# %%
def sample_minibatches(inputs,targets, chunksize, shuffle=True):
    # Provide chunks one by one
    
    assert inputs.shape[0] == targets.shape[0]
    if shuffle:
        indices = np.arange(inputs.shape[0])
        np.random.shuffle(indices)
    for start_idx in range(0, inputs.shape[0] - chunksize + 1, chunksize):
        if shuffle:
            excerpt = indices[start_idx:start_idx + chunksize]
        else:
            excerpt = slice(start_idx, start_idx + chunksize)
        yield inputs[excerpt], targets[excerpt]

# %%
def main():
    
    # generate a random distribution and plot it.
	np.random.seed(0)
	X, Y = datasets.make_moons(1000, noise = 0.2)
	plt.scatter(X[:,0], X[:,1], s=40 , c=Y, cmap = plt.cm.Spectral)
	plt.show()
	batcherator = sample_minibatches(X,Y,100)

	# Train model
	for X_chunk, y_chunk in batcherator:
		model = build_training_model(X_chunk, y_chunk, 25)
	print(model)
    # Now make predictions with trained model
    # y_predicted = model.predict(X_test)

	# model = build_training_model(X, Y, 50)
	draw_visualization(X, Y, model)


if __name__ == "__main__":
    main()
# Out:
# Loss after iteration 0: 0.582588
# Loss after iteration 500: 0.020618
# Loss after iteration 1000: 0.008735
# Loss after iteration 1500: 0.004884
# Loss after iteration 2000: 0.003206
# Loss after iteration 2500: 0.002332
# Loss after iteration 3000: 0.001816
# Loss after iteration 3500: 0.001482
# Loss after iteration 4000: 0.001252
# Loss after iteration 4500: 0.001086
# Loss after iteration 0: 0.627255
# Loss after iteration 500: 0.114629
# Loss after iteration 1000: 0.076816
# Loss after iteration 1500: 0.069143
# Loss after iteration 2000: 0.064433
# Loss after iteration 2500: 0.060434
# Loss after iteration 3000: 0.056567
# Loss after iteration 3500: 0.052332
# Loss after iteration 4000: 0.047782
# Loss after iteration 4500: 0.043490
# Loss after iteration 0: 0.598462
# Loss after iteration 500: 0.091524
# Loss after iteration 1000: 0.077269
# Loss after iteration 1500: 0.069104
# Loss after iteration 2000: 0.062331
# Loss after iteration 2500: 0.056470
# Loss after iteration 3000: 0.051552
# Loss after iteration 3500: 0.052531
# Loss after iteration 4000: 0.045456
# Loss after iteration 4500: 0.042813
# Loss after iteration 0: 0.517624
# Loss after iteration 500: 0.044009
# Loss after iteration 1000: 0.020318
# Loss after iteration 1500: 0.011259
# Loss after iteration 2000: 0.007259
# Loss after iteration 2500: 0.005193
# Loss after iteration 3000: 0.003985
# Loss after iteration 3500: 0.003212
# Loss after iteration 4000: 0.002682
# Loss after iteration 4500: 0.002300
# Loss after iteration 0: 0.722377
# Loss after iteration 500: 0.038426
# Loss after iteration 1000: 0.019982
# Loss after iteration 1500: 0.012498
# Loss after iteration 2000: 0.008729
# Loss after iteration 2500: 0.006541
# Loss after iteration 3000: 0.005148
# Loss after iteration 3500: 0.004201
# Loss after iteration 4000: 0.003525
# Loss after iteration 4500: 0.003024
# Loss after iteration 0: 0.551131
# Loss after iteration 500: 0.020750
# Loss after iteration 1000: 0.011022
# Loss after iteration 1500: 0.007020
# Loss after iteration 2000: 0.004878
# Loss after iteration 2500: 0.003612
# Loss after iteration 3000: 0.002809
# Loss after iteration 3500: 0.002269
# Loss after iteration 4000: 0.001890
# Loss after iteration 4500: 0.001613
# Loss after iteration 0: 0.546529
# Loss after iteration 500: 0.075165
# Loss after iteration 1000: 0.048978
# Loss after iteration 1500: 0.033104
# Loss after iteration 2000: 0.025072
# Loss after iteration 2500: 0.020353
# Loss after iteration 3000: 0.017185
# Loss after iteration 3500: 0.014861
# Loss after iteration 4000: 0.013053
# Loss after iteration 4500: 0.011592
# Loss after iteration 0: 0.558385
# Loss after iteration 500: 0.063040
# Loss after iteration 1000: 0.049341
# Loss after iteration 1500: 0.043087
# Loss after iteration 2000: 0.039096
# Loss after iteration 2500: 0.035722
# Loss after iteration 3000: 0.031801
# Loss after iteration 3500: 0.025891
# Loss after iteration 4000: 0.020180
# Loss after iteration 4500: 0.014563
# Loss after iteration 0: 0.369220
# Loss after iteration 500: 0.035484
# Loss after iteration 1000: 0.018727
# Loss after iteration 1500: 0.014286
# Loss after iteration 2000: 0.011886
# Loss after iteration 2500: 0.010171
# Loss after iteration 3000: 0.008785
# Loss after iteration 3500: 0.007609
# Loss after iteration 4000: 0.006596
# Loss after iteration 4500: 0.005726
# Loss after iteration 0: 0.604453
# Loss after iteration 500: 0.099021
# Loss after iteration 1000: 0.089542
# Loss after iteration 1500: 0.083867
# Loss after iteration 2000: 0.078671
# Loss after iteration 2500: 0.073023
# Loss after iteration 3000: 0.067730
# Loss after iteration 3500: 0.063033
# Loss after iteration 4000: 0.060457
# Loss after iteration 4500: 0.056086
# {'W1': array([[ 2.8019647 ,  0.69782489,  1.22459169,  2.93709243,  2.1787522 ,
#         -0.8665978 ,  0.51655138, -0.39046085,  0.8701405 ,  2.03270455,
#         -0.38273872,  7.58029435,  0.61799643,  0.72464139,  1.79500864,
#          0.64511888,  3.70028626,  0.10865594,  0.27620078, -0.74564403,
#         -7.41948966,  0.6338225 ,  0.53274622, -1.50659043,  4.75908705],
#        [-4.70150966, -0.35903087, -0.49768167,  0.74369856,  4.33130342,
#          0.44184163, -0.04584727, -0.55843554, -1.57888184, -0.89890402,
#          0.18201734, -1.10349899,  0.92752528, -0.54579381, -0.74559887,
#         -1.16372191, -1.24395899, -1.52514795,  2.98117999, -0.54307328,
#         -0.17510345, -1.17155033,  0.19147931, -5.06726518, -2.7085159 ]]), 'b1': array([[ 1.22693765, -0.85478499, -1.74100951,  1.08581288, -0.16188456,
#          1.19557785, -0.1808552 , -0.08385936,  0.66220644, -2.73240052,
#         -0.01968799, -0.34125121, -0.00967447, -0.81457724, -2.4489864 ,
#         -0.02675353, -2.05912049, -0.0331916 ,  0.00888415, -0.07875382,
#          4.99570739,  0.23342364, -0.07148327,  0.74199799,  2.29752524]]), 'W2': array([[-2.83936783,  2.73816232],
#        [-1.13028786,  0.79368761],
#        [-1.40231399,  1.48194477],
#        [-1.87596992,  1.94939967],
#        [-2.33883469,  2.14041661],
#        [ 1.04289163, -1.24826491],
#        [-0.82307977,  0.31772708],
#        [ 0.22659871, -0.27124587],
#        [-1.69209817,  1.45977945],
#        [-2.28444697,  2.11422959],
#        [ 0.41455777, -0.24379901],
#        [ 4.02263677, -4.04162661],
#        [-0.18897436,  0.13276243],
#        [-1.21709006,  0.92860673],
#        [-1.96267757,  1.91185489],
#        [-1.49587631,  1.4432753 ],
#        [ 2.424628  , -2.63767634],
#        [-0.09302863,  0.7664812 ],
#        [ 1.11593582, -0.91716124],
#        [ 0.28902902, -0.29227294],
#        [-5.82647346,  5.98950987],
#        [-1.35440616,  1.59020701],
#        [-0.41550884,  0.62703646],
#        [-2.33945083,  2.69693305],
#        [-3.58807821,  3.69333092]]), 'b2': array([[ 0.15492565, -0.15492565]])}
